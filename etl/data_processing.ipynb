# %% [markdown]
# # Road Safety Data Warehousing and Analytics
# **ETL, Star Schema Design, SQL Analytics & Association Rule Mining**
#
# This notebook presents a data warehousing and analytics pipeline built on
# real-world road safety datasets.
#
# The project focuses on:
# - integrating heterogeneous raw data sources using Python-based ETL,
# - designing a dimensional data warehouse (star schema),
# - performing analytical SQL queries for business-style insights,
# - and applying association rule mining to discover meaningful patterns
#   in road fatality data.
#
# The workflow reflects a typical analytical data engineering process,
# from raw data preparation to structured storage and downstream analysis.

# %% [markdown]
# ### Academic Context
#
# This work was completed as a **group project (2 members)** for
# **CITS5504 – Data Warehousing**, University of Western Australia.
#
# **Contributors**:
# - Boya Zhang
# - Lyu Lu
#
# **Date**: April 2025

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# **Importing the libraries**

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import modules for association rule mining
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# **Loading the datasets**

# %%
# Load fatality data
fatalities = pd.read_excel("./DataResource/bitre_fatalities_dec2024.xlsx", 
                           sheet_name="BITRE_Fatality",
                           skiprows=4,
                           header=0
                          )

# Load crash data
crashes = pd.read_excel("./DataResource/bitre_fatal_crashes_dec2024.xlsx", 
                           sheet_name="BITRE_Fatal_Crash",
                           skiprows=4,
                           header=0
                          )

# Load population LGA data
population_LGA = pd.read_excel(("./DataResource/"
                           "Population estimates by LGA, Significant Urban Area, "
                           "Remoteness Area and electoral division, "
                           "2001 to 2024.xlsx"),
                           sheet_name="Table 1",
                           skiprows=5,
                           header=None
                          )

# Load dwelling data
dwelling = pd.read_csv("./DataResource/LGA (count of dwellings).csv", 
                       skiprows=10, 
                       header=0, 
                       index_col=False
                      )

# Load population state data
population_state = pd.read_excel("./DataResource/population_state.xlsx",
                           sheet_name="state",
                           header=0
                          )

# %% [markdown]
# ## 2. Data Exploration

# %% [markdown]
# **Data structure and content**

# %%
# Display shapes of datasets
print("Fatalities shape:", fatalities.shape)
print("Crashes shape:", crashes.shape)
print("Population LGA shape:", population_LGA.shape)
print("Population State shape:", population_state.shape)
print("Dwelling shape:", dwelling.shape)
# Out:
# Fatalities shape: (56874, 23)
# Crashes shape: (51284, 23)
# Population LGA shape: (552, 26)
# Population State shape: (44, 9)
# Dwelling shape: (561, 2)

# %%
# Top few rows
fatalities.head()
# Out:
#    Crash ID State  Month  Year Dayweek      Time Crash Type Bus Involvement  \
# 0  20241115   NSW     12  2024  Friday  04:00:00     Single              No
# 1  20241125   NSW     12  2024  Friday  06:15:00     Single              No
# 2  20246013   Tas     12  2024  Friday  09:43:00   Multiple              No
# 3  20241002   NSW     12  2024  Friday  10:35:00   Multiple              No
# 4  20242261   Vic     12  2024  Friday  11:30:00   Multiple              -9
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age  \
# 0                            No                            No  ...  74
# 1                            No                            No  ...  19
# 2                            No                            No  ...  33
# 3                            No                            No  ...  32
# 4                            -9                            -9  ...  62
#
#   National Remoteness Areas                           SA4 Name 2021  \
# 0  Inner Regional Australia                                Riverina
# 1  Inner Regional Australia  Sydney - Baulkham Hills and Hawkesbury
# 2  Inner Regional Australia               Launceston and North East
# 3  Outer Regional Australia              New England and North West
# 4                   Unknown                                     NaN
#
#    National LGA Name 2021         National Road Type Christmas Period  \
# 0             Wagga Wagga              Arterial Road              Yes
# 1              Hawkesbury                 Local Road               No
# 2       Northern Midlands                 Local Road              Yes
# 3       Armidale Regional  National or State Highway               No
# 4                     NaN               Undetermined               No
#
#   Easter Period Age Group Day of week Time of day
# 0            No  65_to_74     Weekday       Night
# 1            No  17_to_25     Weekday         Day
# 2            No  26_to_39     Weekday         Day
# 3            No  26_to_39     Weekday         Day
# 4            No  40_to_64     Weekday         Day
#
# [5 rows x 23 columns]

# %%
crashes.head()
# Out:
#    Crash ID State  Month  Year Dayweek      Time Crash Type  \
# 0  20241115   NSW     12  2024  Friday  04:00:00     Single
# 1  20241125   NSW     12  2024  Friday  06:15:00     Single
# 2  20246013   Tas     12  2024  Friday  09:43:00   Multiple
# 3  20241002   NSW     12  2024  Friday  10:35:00   Multiple
# 4  20242261   Vic     12  2024  Friday  11:30:00   Multiple
#
#    Number Fatalities Bus \nInvolvement Heavy Rigid Truck Involvement  ...  \
# 0                  1                No                            No  ...
# 1                  1                No                            No  ...
# 2                  1                No                            No  ...
# 3                  1                No                            No  ...
# 4                  1                -9                            -9  ...
#
#                             SA4 Name 2021 National LGA Name 2021  \
# 0                                Riverina            Wagga Wagga
# 1  Sydney - Baulkham Hills and Hawkesbury             Hawkesbury
# 2               Launceston and North East      Northern Midlands
# 3              New England and North West      Armidale Regional
# 4                                     NaN                    NaN
#
#           National Road Type Christmas Period Easter Period Day of week  \
# 0              Arterial Road              Yes            No     Weekday
# 1                 Local Road               No            No     Weekday
# 2                 Local Road              Yes            No     Weekday
# 3  National or State Highway               No            No     Weekday
# 4               Undetermined               No            No     Weekday
#
#   Time of Day Unnamed: 20 Unnamed: 21 Unnamed: 22
# 0       Night         NaN         NaN         NaN
# 1         Day         NaN         NaN         NaN
# 2         Day         NaN         NaN         NaN
# 3         Day         NaN         NaN         NaN
# 4         Day         NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
population_LGA.head()
# Out:
#          0             1      2      3      4      5      6      7      8   \
# 0       NaN           NaN   2001   2002   2003   2004   2005   2006   2007
# 1  LGA code  LGA name (a)    no.    no.    no.    no.    no.    no.    no.
# 2     10050        Albury  45265  45816  46180  46505  47004  47566  48140
# 3     10180      Armidale  27906  27774  27610  27410  27350  27377  27468
# 4     10250       Ballina  37856  38417  38870  39120  39305  39537  39824
#
#       9   ...     16     17     18     19     20     21     22     23     24  \
# 0   2008  ...   2015   2016   2017   2018   2019   2020   2021   2022   2023
# 1    no.  ...    no.    no.    no.    no.    no.    no.    no.    no.    no.
# 2  48518  ...  51486  52171  53056  53922  54657  55466  56067  56665  57509
# 3  27788  ...  29160  29310  29519  29631  29701  29600  29332  29361  29588
# 4  40020  ...  42336  42993  43652  44385  44997  45663  46196  46849  47277
#
#       25
# 0   2024
# 1    no.
# 2  58317
# 3  29646
# 4  47935
#
# [5 rows x 26 columns]

# %%
population_state.head()
# Out:
#    Unnamed: 0      NSW      Vic      Qld       SA       WA     Tas      NT  \
# 0        1981  5249455  3957333  2367477  1321235  1311284  427925  125186
# 1        1982  5315846  4002731  2442912  1334090  1348096  430308  131517
# 2        1983  5363744  4045185  2493373  1349553  1375244  433909  137942
# 3        1984  5416536  4086549  2535976  1362611  1397817  438866  143934
# 4        1985  5478254  4129796  2583368  1373324  1427370  443548  150596
#
#       ACT
# 0  228782
# 1  233778
# 2  240055
# 3  246259
# 4  253446

# %%
dwelling.head()
# Out:
#             LGA (EN) Unnamed: 1
# 0             Albury      25430
# 1  Armidale Regional      12955
# 2            Ballina      20889
# 3          Balranald       1091
# 4  Bathurst Regional      18458

# %%
# Data types, non-null counts
fatalities.info()
crashes.info()
population_state.info()
population_LGA.info()
dwelling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56874 entries, 0 to 56873
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       56874 non-null  int64
#  1   State                          56874 non-null  object
#  2   Month                          56874 non-null  int64
#  3   Year                           56874 non-null  int64
#  4   Dayweek                        56874 non-null  object
#  5   Time                           56831 non-null  object
#  6   Crash Type                     56874 non-null  object
#  7   Bus Involvement                56874 non-null  object
#  8   Heavy Rigid Truck Involvement  56874 non-null  object
#  9   Articulated Truck Involvement  56874 non-null  object
#  10  Speed Limit                    56874 non-null  object
#  11  Road User                      56874 non-null  object
#  12  Gender                         56874 non-null  object
#  13  Age                            56874 non-null  int64
#  14  National Remoteness Areas      56874 non-null  object
#  15  SA4 Name 2021                  12699 non-null  object
#  16  National LGA Name 2021         12701 non-null  object
#  17  National Road Type             56874 non-null  object
#  18  Christmas Period               56874 non-null  object
#  19  Easter Period                  56874 non-null  object
#  20  Age Group                      56874 non-null  object
#  21  Day of week                    56874 non-null  object
#  22  Time of day                    56874 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 10.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51284 entries, 0 to 51283
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       51284 non-null  int64
#  1   State                          51284 non-null  object
#  2   Month                          51284 non-null  int64
#  3   Year                           51284 non-null  int64
#  4   Dayweek                        51284 non-null  object
#  5   Time                           51245 non-null  object
#  6   Crash Type                     51284 non-null  object
#  7   Number Fatalities              51284 non-null  int64
#  8   Bus
# Involvement               51284 non-null  object
#  9   Heavy Rigid Truck Involvement  51284 non-null  object
#  10  Articulated Truck Involvement  51284 non-null  object
#  11  Speed Limit                    51284 non-null  object
#  12  National Remoteness Areas      51284 non-null  object
#  13  SA4 Name 2021                  11705 non-null  object
#  14  National LGA Name 2021         11706 non-null  object
#  15  National Road Type             51284 non-null  object
#  16  Christmas Period               51284 non-null  object
#  17  Easter Period                  51284 non-null  object
#  18  Day of week                    51284 non-null  object
#  19  Time of Day                    51284 non-null  object
#  20  Unnamed: 20                    0 non-null      float64
#  21  Unnamed: 21                    1 non-null      float64
#  22  Unnamed: 22                    1 non-null      float64
# dtypes: float64(3), int64(4), object(16)
# memory usage: 9.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  44 non-null     int64
#  1   NSW         44 non-null     int64
#  2   Vic         44 non-null     int64
#  3   Qld         44 non-null     int64
#  4   SA          44 non-null     int64
#  5   WA          44 non-null     int64
#  6   Tas         44 non-null     int64
#  7   NT          44 non-null     int64
#  8   ACT         44 non-null     int64
# dtypes: int64(9)
# memory usage: 3.2 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       550 non-null    object
#  1   1       549 non-null    object
#  2   2       550 non-null    object
#  3   3       550 non-null    object
#  4   4       550 non-null    object
#  5   5       550 non-null    object
#  6   6       550 non-null    object
#  7   7       550 non-null    object
#  8   8       550 non-null    object
#  9   9       550 non-null    object
#  10  10      550 non-null    object
#  11  11      550 non-null    object
#  12  12      550 non-null    object
#  13  13      550 non-null    object
#  14  14      550 non-null    object
#  15  15      550 non-null    object
#  16  16      550 non-null    object
#  17  17      550 non-null    object
#  18  18      550 non-null    object
#  19  19      550 non-null    object
#  20  20      550 non-null    object
#  21  21      550 non-null    object
#  22  22      550 non-null    object
#  23  23      550 non-null    object
#  24  24      550 non-null    object
#  25  25      550 non-null    object
# dtypes: object(26)
# memory usage: 112.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LGA (EN)    561 non-null    object
#  1   Unnamed: 1  558 non-null    object
# dtypes: object(2)
# memory usage: 8.9+ KB

# %% [markdown]
# **Notes**
#
# - The fatalities and crash datasets contain similar information. Only the fatalities dataset will be used for further processing, as it includes all relevant individual-level details for each fatality.
# - LGA name fields differ across datasets and will be as key fields for joining
# - Some LGA fields are missing and will remain as NaN — rows will be kept to preserve historical fatality records.
# - Population data is in wide format and will be reshaped; dwelling data requires column renaming.

# %% [markdown]
# ## 3. Data Cleaning and Preparation

# %% [markdown]
# **Data processing**

# %%
population_LGA.head()
# Out:
#          0             1      2      3      4      5      6      7      8   \
# 0       NaN           NaN   2001   2002   2003   2004   2005   2006   2007
# 1  LGA code  LGA name (a)    no.    no.    no.    no.    no.    no.    no.
# 2     10050        Albury  45265  45816  46180  46505  47004  47566  48140
# 3     10180      Armidale  27906  27774  27610  27410  27350  27377  27468
# 4     10250       Ballina  37856  38417  38870  39120  39305  39537  39824
#
#       9   ...     16     17     18     19     20     21     22     23     24  \
# 0   2008  ...   2015   2016   2017   2018   2019   2020   2021   2022   2023
# 1    no.  ...    no.    no.    no.    no.    no.    no.    no.    no.    no.
# 2  48518  ...  51486  52171  53056  53922  54657  55466  56067  56665  57509
# 3  27788  ...  29160  29310  29519  29631  29701  29600  29332  29361  29588
# 4  40020  ...  42336  42993  43652  44385  44997  45663  46196  46849  47277
#
#       25
# 0   2024
# 1    no.
# 2  58317
# 3  29646
# 4  47935
#
# [5 rows x 26 columns]

# %%
# Clean population_LGA data
population_LGA.iloc[0, :2] = population_LGA.iloc[1, :2]
population_LGA.columns = population_LGA.iloc[0]
population_LGA = population_LGA.drop(index=[0, 1]).reset_index(drop=True)

# Reshape population_LGA data from wide to long format
population_LGA = population_LGA.melt(
    id_vars=["LGA code", "LGA name (a)"],
    var_name="Year",
    value_name="Population_LGA"
)

# drop rows where LGA name or Year is missing
population_LGA = population_LGA.dropna(subset=["LGA name (a)", "Year"])

# %%
population_state.head()
# Out:
#    Unnamed: 0      NSW      Vic      Qld       SA       WA     Tas      NT  \
# 0        1981  5249455  3957333  2367477  1321235  1311284  427925  125186
# 1        1982  5315846  4002731  2442912  1334090  1348096  430308  131517
# 2        1983  5363744  4045185  2493373  1349553  1375244  433909  137942
# 3        1984  5416536  4086549  2535976  1362611  1397817  438866  143934
# 4        1985  5478254  4129796  2583368  1373324  1427370  443548  150596
#
#       ACT
# 0  228782
# 1  233778
# 2  240055
# 3  246259
# 4  253446

# %%
# Transformation
population_state = population_state.rename(columns={population_state.columns[0]:"Year"})
population_state_long = population_state.melt(
  id_vars="Year",
  var_name= "State",
  value_name="Population_State"
)
population_state_long["Year"] = pd.to_numeric(population_state_long["Year"], errors="coerce")
population_state_long["Population_State"] = pd.to_numeric(population_state_long["Population_State"], errors="coerce")

# %%
# population_state = population_state_long
# population_state.head()
# Out:
#    Year State  Population_State
# 0  1981   NSW           5249455
# 1  1982   NSW           5315846
# 2  1983   NSW           5363744
# 3  1984   NSW           5416536
# 4  1985   NSW           5478254

# %% [markdown]
# **Data merging**

# %%
population_LGA.head()
# Out:
#   LGA code LGA name (a)  Year Population_LGA
# 0    10050       Albury  2001          45265
# 1    10180     Armidale  2001          27906
# 2    10250      Ballina  2001          37856
# 3    10300    Balranald  2001           2751
# 4    10470     Bathurst  2001          35504

# %%
# Merge dwellings with population_LGA LGA
dwelling.columns = ["LGA name (a)", "Dwelling"]
population_LGA = population_LGA.merge(dwelling, on="LGA name (a)", how="left")

# Convert data types to numeric types
population_LGA["Population_LGA"] = pd.to_numeric(population_LGA["Population_LGA"],errors="coerce")
population_LGA["Dwelling"] = pd.to_numeric(population_LGA["Dwelling"], errors="coerce")
population_LGA = population_LGA.drop(columns=["LGA code"])

population_LGA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13152 entries, 0 to 13151
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LGA name (a)    13152 non-null  object
#  1   Year            13152 non-null  object
#  2   Population_LGA  13152 non-null  int64
#  3   Dwelling        12720 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 411.1+ KB

# %%
# Merge population LGA and dwelling info into fatalities
fatalities = fatalities.merge(
    population_LGA, left_on=["National LGA Name 2021", "Year"],
    right_on=["LGA name (a)", "Year"],
    how="left"
)

# Merge population LGA and dwelling info into fatalities
fatalities = fatalities.merge(
    population_state, left_on=["State", "Year"],
    right_on=["State", "Year"],
    how="left"
)

fatalities.shape
# Out:
# (56874, 27)

# %% [markdown]
# ### Missing values

# %%
# Replace unknown invalid or missing codes with NaN
fatalities = fatalities.replace(
    [-9, "-9", "unknown", "Unknown", "Other/-9", "Undetermined"],
    np.nan
)
# whether we can just replace these values to "unknown"
# Out:
# /var/folders/j6/bx5wzhgd4lxc5fnmfg3s5nvw0000gn/T/ipykernel_77350/82292955.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   fatalities = fatalities.replace(

# %% [markdown]
# - populationis reshaped from wide to long format and merged with dwelling.
# - fatalities is merged with population and dwelling based on LGA and year.
# - Non-standard values are converted as NaN. These rows are kept in the dataset to preserve historical records.

# %% [markdown]
# ## 4. Dimension Tables

# %% [markdown]
# **Location Dimension**

# %%
# Create location dimension

location_df = fatalities[["National LGA Name 2021", "State"]].copy()
location_df["National LGA Name 2021"] = location_df["National LGA Name 2021"].fillna("Unknown")  # Create "Unknown" category
location_df = location_df.drop_duplicates()
location_df.insert(0, "LocationID", range(1, 1 + len(location_df)))
location_df.head()
# Out:
#    LocationID National LGA Name 2021 State
# 0           1            Wagga Wagga   NSW
# 1           2             Hawkesbury   NSW
# 2           3      Northern Midlands   Tas
# 3           4      Armidale Regional   NSW
# 4           5                Unknown   Vic

# %% [markdown]
# - Extracts unique LGA and State combinations.
# - Fill LGA with "Unknown" category.
# - LocationID as primary key.

# %% [markdown]
# **Date Dimension**

# %%
# Create date dimension
date_df = fatalities[["Month", "Year"]].drop_duplicates().dropna()

# Add Quarter column
date_df["Quarter"] = ((date_df["Month"] - 1) // 3) + 1

date_df.insert(0, "DateID", range(1, 1 + len(date_df)))
date_df.head()
# Out:
#      DateID  Month  Year  Quarter
# 0         1     12  2024        4
# 113       2     11  2024        4
# 244       3     10  2024        4
# 359       4      9  2024        3
# 454       5      8  2024        3

# %%
date_df["Year"].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003,
#        2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992,
#        1991, 1990, 1989])

# %% [markdown]
# - Extracts unique Year, Month, and Dayweek combinations.
# - Adds Quarter column.
# - DateID as primary key.

# %% [markdown]
# **Dayweek Dimension**

# %%
# Create dayweek_df
dayweek_df = fatalities[["Dayweek"]].drop_duplicates().dropna()
dayweek_df.insert(0, "DayweekID", range(1, 1 + len(dayweek_df)))
dayweek_df
# Out:
#      DayweekID    Dayweek
# 0            1     Friday
# 14           2     Monday
# 31           3   Saturday
# 56           4     Sunday
# 83           5   Thursday
# 92           6    Tuesday
# 105          7  Wednesday

# %% [markdown]
# **Date of week Dimension**

# %%
# Create day_of_week_df and 

day_of_week_df = fatalities[["Day of week"]].drop_duplicates().dropna()
day_of_week_df.insert(0, "DayofWeekID", range(1, 1 + len(day_of_week_df)))
day_of_week_df
# Out:
#    DayofWeekID Day of week
# 0            1     Weekday
# 8            2     Weekend

# %% [markdown]
# We noticed that some “Dayweek” values were misclassified. Since the “Day of week” feature is not useful for further analysis, we decided not to correct them.

# %% [markdown]
# **Holiday Dimension**

# %%
# Create holiday status column in fatalities
fatalities["Holiday Status"] = np.where(
    (fatalities["Christmas Period"] == "Yes") | 
    (fatalities["Easter Period"] == "Yes"), "Holiday", "Non-holiday")

# %%
# Create holiday dimension
holiday_df = fatalities[["Holiday Status"]].drop_duplicates().dropna()
holiday_df.insert(0, "HolidayID", range(1, 1 + len(holiday_df)))
holiday_df
# Out:
#    HolidayID Holiday Status
# 0          1        Holiday
# 1          2    Non-holiday

# %% [markdown]
# - Creates Holiday Status in fatalities based on Christmas Period and Easter Period.
# - Extracts unique Holiday Status values.
# - HolidayID as primary key.

# %% [markdown]
# **Time Dimension**

# %%
# Create time dimension
time_df = fatalities[["Time of day"]].drop_duplicates().dropna()
time_df.insert(0, "TimeID", range(1, 1 + len(time_df)))
time_df
# Out:
#    TimeID Time of day
# 0       1       Night
# 1       2         Day

# %% [markdown]
# - Extracts unique Time of day values: Day and Night.
# - TimeID as primary key.

# %% [markdown]
# **Crash Type Dimension**

# %%
# Create crash type dimension
crashtype_df = fatalities[["Crash Type"]].drop_duplicates().dropna()
crashtype_df.insert(0, "CrashTypeID", range(1, 1 + len(crashtype_df)))
crashtype_df
# Out:
#    CrashTypeID Crash Type
# 0            1     Single
# 2            2   Multiple

# %% [markdown]
# - Extracts unique Crash Type values: Single and Multiple.
# - CrashTypeID as primary key.

# %% [markdown]
# **Involvement Dimension**

# %%
# Create involvement columns in fatalities and fill missing values
fatalities[["Bus Involvement", "Heavy Rigid Truck Involvement", "Articulated Truck Involvement"]] = (
    fatalities[["Bus Involvement", "Heavy Rigid Truck Involvement", "Articulated Truck Involvement"]]
    .fillna("No")
)

# Create Involvement Type column based on involvement values
fatalities["Involvement Type"] = np.select(
    [
        (fatalities["Bus Involvement"] == "Yes") & (fatalities["Heavy Rigid Truck Involvement"] == "No") 
            & (fatalities["Articulated Truck Involvement"] == "No"),
        (fatalities["Bus Involvement"] == "No") & (fatalities["Heavy Rigid Truck Involvement"] == "Yes") 
            & (fatalities["Articulated Truck Involvement"] == "No"),
        (fatalities["Bus Involvement"] == "No") & (fatalities["Heavy Rigid Truck Involvement"] == "No") 
            & (fatalities["Articulated Truck Involvement"] == "Yes"),
        (fatalities["Bus Involvement"] == "Yes") & (fatalities["Heavy Rigid Truck Involvement"] == "Yes") 
            & (fatalities["Articulated Truck Involvement"] == "No"),  # Add Bus/Heavy Rigid
        (fatalities["Bus Involvement"] == "Yes") & (fatalities["Heavy Rigid Truck Involvement"] == "No") 
            & (fatalities["Articulated Truck Involvement"] == "Yes"),
        (fatalities["Bus Involvement"] == "No") & (fatalities["Heavy Rigid Truck Involvement"] == "Yes") 
            & (fatalities["Articulated Truck Involvement"] == "Yes"),
    ], 
    ["Bus", "Heavy Rigid Truck", "Articulated Truck", "Bus/Heavy Rigid", "Bus/Articulated Truck", "Heavy Rigid/Articulated Truck"],
    default=None
)

# %%
# Create involvement dimension
involvement_df = fatalities[["Involvement Type"]].drop_duplicates().dropna()
involvement_df.insert(0, "InvolvementID", range(1, 1 + len(involvement_df)))
involvement_df
# Out:
#      InvolvementID               Involvement Type
# 13               1              Articulated Truck
# 32               2          Bus/Articulated Truck
# 41               3              Heavy Rigid Truck
# 102              4  Heavy Rigid/Articulated Truck
# 103              5                            Bus
# 547              6                Bus/Heavy Rigid

# %% [markdown]
# - Creates Involvement Type in fatalities, classifying combinations like Bus, Heavy Rigid Truck, Articulated Truck, and their combinations.
# - Includes all 6 types: Bus, Heavy Rigid Truck, Articulated Truck, Bus/Heavy Rigid, Bus/Articulated Truck, and Heavy Rigid/Articulated Truck.
# - InvolvementID as primary key.

# %% [markdown]
# **User Dimension**

# %%
# Create user dimension
user_df = fatalities[["Road User"]].drop_duplicates().dropna()
user_df.insert(0, "UserID", range(1, 1 + len(user_df)))
user_df
# Out:
#      UserID                     Road User
# 0         1                        Driver
# 4         2                     Passenger
# 6         3              Motorcycle rider
# 12        4                    Pedestrian
# 50        5                 Pedal cyclist
# 488       6  Motorcycle pillion passenger

# %% [markdown]
# - Extracts unique Road User values.
# - UserID as primary key.

# %% [markdown]
# **Road Dimension**

# %%
# Create road dimension
road_df = fatalities[["National Road Type"]].drop_duplicates().dropna()
road_df.insert(0, "RoadID", range(1, 1 + len(road_df)))
road_df
# Out:
#      RoadID         National Road Type
# 0         1              Arterial Road
# 1         2                 Local Road
# 3         3  National or State Highway
# 6         4          Sub-arterial Road
# 17        5             Collector Road
# 154       6    Pedestrian Thoroughfare
# 283       7                Access road
# 970       8                     Busway

# %% [markdown]
# - Extracts unique National Road Type values.
# - RoadID as primary key.

# %% [markdown]
# **Speed Limit Dimension**

# %%
# Create speed limit categories in fatalities

# Very Low : 0-30
# Low: 31-60
# Medium: 61-90
# High: 91-110
# Very high: >110

fatalities["Speed Limit Category"] = np.select(
    [(fatalities["Speed Limit"] == 5) | (fatalities["Speed Limit"] == 10) | 
        (fatalities["Speed Limit"] == 15)| (fatalities["Speed Limit"] == 20) | 
        (fatalities["Speed Limit"] == 25) | (fatalities["Speed Limit"] == 30),  # Very low
    (fatalities["Speed Limit"] == '<40') | (fatalities["Speed Limit"] == 40) | (fatalities["Speed Limit"] == 50) 
        | (fatalities["Speed Limit"] == 60),  # Low
    (fatalities["Speed Limit"] == 70) | (fatalities["Speed Limit"] == 75) | (fatalities["Speed Limit"] == 80) 
        | (fatalities["Speed Limit"] == 90),  # Medium
    (fatalities["Speed Limit"] == 100) | (fatalities["Speed Limit"] == 110),  # High
    (fatalities["Speed Limit"] == 130)  # Very High
    ], ["Very Low", "Low", "Medium", "High", "Very High"], default=None)

# %%
# Create speed limit dimension
speed_limit_df = fatalities[["Speed Limit Category"]].drop_duplicates().dropna()
speed_limit_df.insert(0, "SpeedID", range(1, 1 + len(speed_limit_df)))
speed_limit_df
# Out:
#      SpeedID Speed Limit Category
# 0          1                 High
# 1          2               Medium
# 2          3                  Low
# 63         4             Very Low
# 554        5            Very High

# %% [markdown]
# - Extracts unique Speed Limit Category values from fatalities.
# - Categories: Very Low, Low, Medium, High, and Very High.
# - SpeedID as primary key.

# %% [markdown]
# **Gender Dimension**

# %%
# Create gender dimension
gender_df = fatalities[["Gender"]].drop_duplicates().dropna()
gender_df.insert(0, "GenderID", range(1, 1 + len(gender_df)))
gender_df
# Out:
#    GenderID  Gender
# 0         1    Male
# 1         2  Female

# %% [markdown]
# - Extracts unique `Gender` values: `Male` and `Female`.
# - `GenderID` as primary key.

# %% [markdown]
# **Age Group Dimension**

# %%
# Create age group dimension
age_group_df = fatalities[["Age Group"]].drop_duplicates().dropna()
age_group_df.insert(0, "AgeGroupID", range(1, 1 + len(age_group_df)))
age_group_df
# Out:
#     AgeGroupID    Age Group
# 0            1     65_to_74
# 1            2     17_to_25
# 2            3     26_to_39
# 4            4     40_to_64
# 18           5  75_or_older
# 20           6      0_to_16

# %% [markdown]
# - Extracts unique Age Group values from fatalities.
# - AgeGroupID as primary key.

# %% [markdown]
# ## 5. Fact Table

# %%
# Create fact table
fact_df = fatalities.copy()
print(fact_df.columns.tolist())
# Out:
# ['Crash ID', 'State', 'Month', 'Year', 'Dayweek', 'Time', 'Crash Type', 'Bus Involvement', 'Heavy Rigid Truck Involvement', 'Articulated Truck Involvement', 'Speed Limit', 'Road User', 'Gender', 'Age', 'National Remoteness Areas', 'SA4 Name 2021', 'National LGA Name 2021', 'National Road Type', 'Christmas Period', 'Easter Period', 'Age Group', 'Day of week', 'Time of day', 'LGA name (a)', 'Population_LGA', 'Dwelling', 'Population_State', 'Holiday Status', 'Involvement Type', 'Speed Limit Category']

# %% [markdown]
# **Merge with dimension tables**

# %%
# Merge with date dimension
fact_df = fact_df.merge(date_df, on = ["Month", "Year"], how="left")

# Merge with location dimension
fact_df["National LGA Name 2021"] = fact_df["National LGA Name 2021"].fillna("Unknown")
fact_df = fact_df.merge(location_df, on = ["National LGA Name 2021", "State"], how="left")

dfs = [dayweek_df, day_of_week_df, holiday_df, time_df, crashtype_df, user_df, road_df, gender_df, age_group_df, 
       speed_limit_df, involvement_df]
for df in dfs:
    fact_df = fact_df.merge(df, on = df.columns[1], how="left")

# Select columns
fact_df = fact_df[["DateID", "LocationID",  "DayweekID",  "DayofWeekID", "HolidayID", "TimeID", "CrashTypeID", "UserID", "RoadID", 
                   "GenderID", "AgeGroupID", "SpeedID", "InvolvementID", "Population_LGA", "Population_State", "Dwelling"]]

# %%
# Create measures
fact_df["Fatality"] = 1
fact_df["Fatality Rate per Population LGA"] = (fact_df["Fatality"] / 
                                           fact_df["Population_LGA"]).where(fact_df["Population_LGA"].notna())*100000
fact_df["Fatality Rate per Population State"] = (fact_df["Fatality"] / 
                                           fact_df["Population_State"]).where(fact_df["Population_State"].notna())*100000
fact_df["Fatality Rate per Dwelling"] = (fact_df["Fatality"] / 
                                         fact_df["Dwelling"]).where(fact_df["Dwelling"].notna())*100000


fact_df.insert(0, "FatalitiesID", range(1, 1+len(fact_df)))

# Convert columns data_type
for col in fact_df.columns:
    if col not in ["Fatality Rate per Population LGA", "Fatality Rate per Population State", "Fatality Rate per Dwelling"]:
        fact_df[col] = fact_df[col].astype('Int64') 

# Drop the features population and dwelling, as these features cannot be additive
fact_df = fact_df.drop(["Population_LGA","Population_State","Dwelling"],axis=1)
fact_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56874 entries, 0 to 56873
# Data columns (total 18 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   FatalitiesID                        56874 non-null  Int64
#  1   DateID                              56874 non-null  Int64
#  2   LocationID                          56874 non-null  Int64
#  3   DayweekID                           56874 non-null  Int64
#  4   DayofWeekID                         56861 non-null  Int64
#  5   HolidayID                           56874 non-null  Int64
#  6   TimeID                              56830 non-null  Int64
#  7   CrashTypeID                         56874 non-null  Int64
#  8   UserID                              56742 non-null  Int64
#  9   RoadID                              10738 non-null  Int64
#  10  GenderID                            56840 non-null  Int64
#  11  AgeGroupID                          56757 non-null  Int64
#  12  SpeedID                             55389 non-null  Int64
#  13  InvolvementID                       8382 non-null   Int64
#  14  Fatality                            56874 non-null  Int64
#  15  Fatality Rate per Population LGA    10495 non-null  float64
#  16  Fatality Rate per Population State  56874 non-null  float64
#  17  Fatality Rate per Dwelling          10300 non-null  float64
# dtypes: Int64(15), float64(3)
# memory usage: 8.6 MB

# %% [markdown]
# - Copy fatalities and merge with dimension tables.
# - Calculate measures: Fatality, Fatality Rate per Population LGA, Fatality Rate per Population State, Fatality Rate per Dwelling.
# - FatalitiesID as the primary key.

# %%
# Export dimension and fact tables to CSV
csv_names = [
    "DimDayweek.csv", "DimDayofWeek.csv", "DimHoliday.csv", "DimTime.csv", "DimCrashType.csv", 
    "DimUser.csv", "DimRoad.csv", "DimGender.csv", "DimAgeGroup.csv", "DimSpeedLimit.csv", 
    "DimInvolvement.csv","DimDate.csv", "DimLocation.csv", "FactFatalities.csv"
]

dfs.extend([date_df, location_df, fact_df])
for i in range(len(dfs)):
    dfs[i].to_csv(f"./DataWarehouse/{csv_names[i]}", index=False)

# %% [markdown]
# ## 6. Associate Rule Mining

# %%
# Load data
df_raw = fatalities.copy()

# %% [markdown]
# **Data Preparation**

# %%
df_raw.shape
# Out:
# (56874, 30)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56874 entries, 0 to 56873
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       56874 non-null  int64
#  1   State                          56874 non-null  object
#  2   Month                          56874 non-null  int64
#  3   Year                           56874 non-null  int64
#  4   Dayweek                        56874 non-null  object
#  5   Time                           56831 non-null  object
#  6   Crash Type                     56874 non-null  object
#  7   Bus Involvement                56874 non-null  object
#  8   Heavy Rigid Truck Involvement  56874 non-null  object
#  9   Articulated Truck Involvement  56874 non-null  object
#  10  Speed Limit                    55389 non-null  object
#  11  Road User                      56742 non-null  object
#  12  Gender                         56840 non-null  object
#  13  Age                            56758 non-null  float64
#  14  National Remoteness Areas      11354 non-null  object
#  15  SA4 Name 2021                  11023 non-null  object
#  16  National LGA Name 2021         11025 non-null  object
#  17  National Road Type             10738 non-null  object
#  18  Christmas Period               56874 non-null  object
#  19  Easter Period                  56874 non-null  object
#  20  Age Group                      56757 non-null  object
#  21  Day of week                    56861 non-null  object
#  22  Time of day                    56830 non-null  object
#  23  LGA name (a)                   10495 non-null  object
#  24  Population_LGA                 10495 non-null  float64
#  25  Dwelling                       10300 non-null  float64
#  26  Population_State               56874 non-null  int64
#  27  Holiday Status                 56874 non-null  object
#  28  Involvement Type               8382 non-null   object
#  29  Speed Limit Category           55389 non-null  object
# dtypes: float64(3), int64(4), object(23)
# memory usage: 13.0+ MB

# %%
df_raw.head()
# Out:
#    Crash ID State  Month  Year Dayweek      Time Crash Type Bus Involvement  \
# 0  20241115   NSW     12  2024  Friday  04:00:00     Single              No
# 1  20241125   NSW     12  2024  Friday  06:15:00     Single              No
# 2  20246013   Tas     12  2024  Friday  09:43:00   Multiple              No
# 3  20241002   NSW     12  2024  Friday  10:35:00   Multiple              No
# 4  20242261   Vic     12  2024  Friday  11:30:00   Multiple              No
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age Group  \
# 0                            No                            No  ...  65_to_74
# 1                            No                            No  ...  17_to_25
# 2                            No                            No  ...  26_to_39
# 3                            No                            No  ...  26_to_39
# 4                            No                            No  ...  40_to_64
#
#   Day of week Time of day       LGA name (a) Population_LGA Dwelling  \
# 0     Weekday       Night        Wagga Wagga        68951.0  28244.0
# 1     Weekday         Day         Hawkesbury        68704.0  25523.0
# 2     Weekday         Day  Northern Midlands        14428.0   6444.0
# 3     Weekday         Day                NaN            NaN      NaN
# 4     Weekday         Day                NaN            NaN      NaN
#
#   Population_State Holiday Status Involvement Type Speed Limit Category
# 0          8511151        Holiday             None                 High
# 1          8511151    Non-holiday             None               Medium
# 2           575959        Holiday             None                  Low
# 3          8511151    Non-holiday             None                 High
# 4          7012962    Non-holiday             None                 None
#
# [5 rows x 30 columns]

# %% [markdown]
# **Features selection**

# %%
# Based on the main risk factors
features = ['Dayweek', 'Road User', 'Gender', 'National Remoteness Areas','National LGA Name 2021', 
            'National Road Type',  'Age Group', 'Day of week', 'Time of day', 'Involvement Type',
            'Speed Limit Category']

# %%
df_select = df_raw[features]
df_select.head()
# Out:
#   Dayweek  Road User  Gender National Remoteness Areas National LGA Name 2021  \
# 0  Friday     Driver    Male  Inner Regional Australia            Wagga Wagga
# 1  Friday     Driver  Female  Inner Regional Australia             Hawkesbury
# 2  Friday     Driver  Female  Inner Regional Australia      Northern Midlands
# 3  Friday     Driver  Female  Outer Regional Australia      Armidale Regional
# 4  Friday  Passenger    Male                       NaN                    NaN
#
#           National Road Type Age Group Day of week Time of day  \
# 0              Arterial Road  65_to_74     Weekday       Night
# 1                 Local Road  17_to_25     Weekday         Day
# 2                 Local Road  26_to_39     Weekday         Day
# 3  National or State Highway  26_to_39     Weekday         Day
# 4                        NaN  40_to_64     Weekday         Day
#
#   Involvement Type Speed Limit Category
# 0             None                 High
# 1             None               Medium
# 2             None                  Low
# 3             None                 High
# 4             None                 None

# %%
# Missing value
df_select.isna().sum().sort_values(ascending=False)
# Out:
# Involvement Type             48492
# National Road Type           46136
# National LGA Name 2021       45849
# National Remoteness Areas    45520
# Speed Limit Category          1485
# Road User                      132
# Age Group                      117
# Time of day                     44
# Gender                          34
# Day of week                     13
# Dayweek                          0
# dtype: int64

# %%
# Replace the nan with Unknow
df_select = df_select.fillna("Unknow")
df_select.isna().sum()
# Out:
# Dayweek                      0
# Road User                    0
# Gender                       0
# National Remoteness Areas    0
# National LGA Name 2021       0
# National Road Type           0
# Age Group                    0
# Day of week                  0
# Time of day                  0
# Involvement Type             0
# Speed Limit Category         0
# dtype: int64

# %%
# Data label
for x,i in enumerate(features):
  df_select.iloc[:,x] = i + ":" + df_select.iloc[:,x].astype(str)

# %%
df_select.head()
# Out:
#           Dayweek            Road User         Gender  \
# 0  Dayweek:Friday     Road User:Driver    Gender:Male
# 1  Dayweek:Friday     Road User:Driver  Gender:Female
# 2  Dayweek:Friday     Road User:Driver  Gender:Female
# 3  Dayweek:Friday     Road User:Driver  Gender:Female
# 4  Dayweek:Friday  Road User:Passenger    Gender:Male
#
#                            National Remoteness Areas  \
# 0  National Remoteness Areas:Inner Regional Austr...
# 1  National Remoteness Areas:Inner Regional Austr...
# 2  National Remoteness Areas:Inner Regional Austr...
# 3  National Remoteness Areas:Outer Regional Austr...
# 4                   National Remoteness Areas:Unknow
#
#                      National LGA Name 2021  \
# 0        National LGA Name 2021:Wagga Wagga
# 1         National LGA Name 2021:Hawkesbury
# 2  National LGA Name 2021:Northern Midlands
# 3  National LGA Name 2021:Armidale Regional
# 4             National LGA Name 2021:Unknow
#
#                              National Road Type           Age Group  \
# 0              National Road Type:Arterial Road  Age Group:65_to_74
# 1                 National Road Type:Local Road  Age Group:17_to_25
# 2                 National Road Type:Local Road  Age Group:26_to_39
# 3  National Road Type:National or State Highway  Age Group:26_to_39
# 4                     National Road Type:Unknow  Age Group:40_to_64
#
#            Day of week        Time of day         Involvement Type  \
# 0  Day of week:Weekday  Time of day:Night  Involvement Type:Unknow
# 1  Day of week:Weekday    Time of day:Day  Involvement Type:Unknow
# 2  Day of week:Weekday    Time of day:Day  Involvement Type:Unknow
# 3  Day of week:Weekday    Time of day:Day  Involvement Type:Unknow
# 4  Day of week:Weekday    Time of day:Day  Involvement Type:Unknow
#
#           Speed Limit Category
# 0    Speed Limit Category:High
# 1  Speed Limit Category:Medium
# 2     Speed Limit Category:Low
# 3    Speed Limit Category:High
# 4  Speed Limit Category:Unknow

# %%
df_select.shape
# Out:
# (56874, 11)

# %% [markdown]
# ### Unknown values

# %%
# TransactionEncoder() function only can handle string type
df_new = df_select.astype(str)

# TransactionEncoder() was designed to covert lists to array
list =df_new.values.tolist()

# Covert the list to one-hot encoded boolean numpy array. 
# Apriori function allows boolean data type only, such as 1 and 0, or FALSE and TRUE.
te = TransactionEncoder()
array_te = te.fit(list).transform(list)

# Check the array
array_te

# Check the colunms
te.columns_

# Apriori function can handle dataframe only, covert the array to a dataframe
df_arm = pd.DataFrame(array_te, columns = te.columns_)

# %%
df_arm.head()
# Out:
#    Age Group:0_to_16  Age Group:17_to_25  Age Group:26_to_39  \
# 0              False               False               False
# 1              False                True               False
# 2              False               False                True
# 3              False               False                True
# 4              False               False               False
#
#    Age Group:40_to_64  Age Group:65_to_74  Age Group:75_or_older  \
# 0               False                True                  False
# 1               False               False                  False
# 2               False               False                  False
# 3               False               False                  False
# 4                True               False                  False
#
#    Age Group:Unknow  Day of week:Unknow  Day of week:Weekday  \
# 0             False               False                 True
# 1             False               False                 True
# 2             False               False                 True
# 3             False               False                 True
# 4             False               False                 True
#
#    Day of week:Weekend  ...  Road User:Unknow  Speed Limit Category:High  \
# 0                False  ...             False                       True
# 1                False  ...             False                      False
# 2                False  ...             False                      False
# 3                False  ...             False                       True
# 4                False  ...             False                      False
#
#    Speed Limit Category:Low  Speed Limit Category:Medium  \
# 0                     False                        False
# 1                     False                         True
# 2                      True                        False
# 3                     False                        False
# 4                     False                        False
#
#    Speed Limit Category:Unknow  Speed Limit Category:Very High  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                         True                           False
#
#    Speed Limit Category:Very Low  Time of day:Day  Time of day:Night  \
# 0                          False            False               True
# 1                          False             True              False
# 2                          False             True              False
# 3                          False             True              False
# 4                          False             True              False
#
#    Time of day:Unknow
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
#
# [5 rows x 569 columns]

# %%
#Find the frequent itemsets
frequent_itemsets = apriori(df_arm,min_support=0.2,use_colnames =True)

#Check the length of rules
frequent_itemsets['length']=frequent_itemsets['itemsets'].apply(lambda x: len(x))

#Assume the length is 2 and the min support is >= 0.3
frequent_itemsets[ (frequent_itemsets['length']==2) & 
                  (frequent_itemsets['support']>=0.3)]
# Out:
#      support                                           itemsets  length
# 22  0.411242                 (Day of week:Weekday, Gender:Male)       2
# 23  0.477037     (Involvement Type:Unknow, Day of week:Weekday)       2
# 24  0.471164  (Day of week:Weekday, National LGA Name 2021:U...       2
# 25  0.467912  (Day of week:Weekday, National Remoteness Area...       2
# 26  0.474329   (Day of week:Weekday, National Road Type:Unknow)       2
# 29  0.395541             (Day of week:Weekday, Time of day:Day)       2
# 30  0.306537                 (Gender:Male, Day of week:Weekend)       2
# 31  0.375356     (Involvement Type:Unknow, Day of week:Weekend)       2
# 32  0.334758  (National LGA Name 2021:Unknow, Day of week:We...       2
# 33  0.332226  (National Remoteness Areas:Unknow, Day of week...       2
# 34  0.336639   (National Road Type:Unknow, Day of week:Weekend)       2
# 40  0.611351             (Involvement Type:Unknow, Gender:Male)       2
# 41  0.575025       (Gender:Male, National LGA Name 2021:Unknow)       2
# 42  0.570542    (Gender:Male, National Remoteness Areas:Unknow)       2
# 43  0.578612           (National Road Type:Unknow, Gender:Male)       2
# 44  0.340138                    (Road User:Driver, Gender:Male)       2
# 45  0.323680           (Speed Limit Category:High, Gender:Male)       2
# 47  0.380543                     (Gender:Male, Time of day:Day)       2
# 48  0.336797                   (Time of day:Night, Gender:Male)       2
# 49  0.690755  (Involvement Type:Unknow, National LGA Name 20...       2
# 50  0.685920  (Involvement Type:Unknow, National Remoteness ...       2
# 51  0.695080  (Involvement Type:Unknow, National Road Type:U...       2
# 52  0.368798        (Involvement Type:Unknow, Road User:Driver)       2
# 53  0.371681  (Involvement Type:Unknow, Speed Limit Category...       2
# 55  0.472465         (Involvement Type:Unknow, Time of day:Day)       2
# 56  0.379400       (Time of day:Night, Involvement Type:Unknow)       2
# 57  0.800366  (National Remoteness Areas:Unknow, National LG...       2
# 58  0.805236  (National Road Type:Unknow, National LGA Name ...       2
# 59  0.360569  (Road User:Driver, National LGA Name 2021:Unknow)       2
# 60  0.369976  (Speed Limit Category:High, National LGA Name ...       2
# 62  0.453230   (Time of day:Day, National LGA Name 2021:Unknow)       2
# 63  0.352147  (Time of day:Night, National LGA Name 2021:Unk...       2
# 64  0.799451  (National Road Type:Unknow, National Remotenes...       2
# 65  0.357474  (Road User:Driver, National Remoteness Areas:U...       2
# 66  0.367162  (Speed Limit Category:High, National Remotenes...       2
# 68  0.449836  (Time of day:Day, National Remoteness Areas:Un...       2
# 69  0.349773  (Time of day:Night, National Remoteness Areas:...       2
# 70  0.362943      (Road User:Driver, National Road Type:Unknow)       2
# 71  0.372015  (National Road Type:Unknow, Speed Limit Catego...       2
# 73  0.456289       (National Road Type:Unknow, Time of day:Day)       2
# 74  0.354134     (Time of day:Night, National Road Type:Unknow)       2

# %%
#Assume the min confidence is 0.5
rules_con = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.5)

# %%
#Assume the min lift is 1
rules_lift = association_rules(frequent_itemsets, metric="lift",min_threshold=1)

#Based on min confidence (=0.5), 
#output antecedents, consequents, support, confidence and lift.
result_arm = rules_con[['antecedents','consequents','support','confidence','lift']]

# %%
#Find the rules whose confidence >= 0.5
new_result_arm = result_arm[result_arm['confidence']>=0.5]

ranked_result = new_result_arm.sort_values(by=['lift', 'confidence'], ascending=False)

ranked_result
# Out:
#                                             antecedents  \
# 1927  (Speed Limit Category:High, National LGA Name ...
# 1926  (Road User:Driver, National Road Type:Unknow, ...
# 1174  (Speed Limit Category:High, National LGA Name ...
# 1171  (Road User:Driver, National Remoteness Areas:U...
# 1932  (Road User:Driver, National Remoteness Areas:U...
# ...                                                 ...
# 850   (Involvement Type:Unknow, Gender:Male, Nationa...
# 1617  (Involvement Type:Unknow, National Remoteness ...
# 1737  (Involvement Type:Unknow, National Road Type:U...
# 2170  (National LGA Name 2021:Unknow, Involvement Ty...
# 501              (Day of week:Weekday, Time of day:Day)
#
#                                             consequents   support  confidence  \
# 1927  (Road User:Driver, National Road Type:Unknow, ...  0.204030    0.551468
# 1926  (Speed Limit Category:High, National LGA Name ...  0.204030    0.571541
# 1174  (Road User:Driver, National Remoteness Areas:U...  0.204311    0.552229
# 1171  (Speed Limit Category:High, National LGA Name ...  0.204311    0.571541
# 1932  (National Road Type:Unknow, Speed Limit Catego...  0.204030    0.570754
# ...                                                 ...       ...         ...
# 850                                   (Time of day:Day)  0.246123    0.504360
# 1617                                  (Time of day:Day)  0.246123    0.504360
# 1737                                  (Time of day:Day)  0.245807    0.504311
# 2170                                  (Time of day:Day)  0.245807    0.504311
# 501              (Involvement Type:Unknow, Gender:Male)  0.204821    0.517825
#
#           lift
# 1927  1.544807
# 1926  1.544807
# 1174  1.544807
# 1171  1.544807
# 1932  1.544368
# ...        ...
# 850   0.885529
# 1617  0.885529
# 1737  0.885444
# 2170  0.885444
# 501   0.847018
#
# [2231 rows x 5 columns]

# %% [markdown]
# ### Without unknown values

# %%
#Load data
df_acc = df_raw[features]

# %%
# Missing value
df_acc.isna().sum().sort_values(ascending=False)
# Out:
# Involvement Type             48492
# National Road Type           46136
# National LGA Name 2021       45849
# National Remoteness Areas    45520
# Speed Limit Category          1485
# Road User                      132
# Age Group                      117
# Time of day                     44
# Gender                          34
# Day of week                     13
# Dayweek                          0
# dtype: int64

# %%
# Drop features
# Considering the missing data and the uncontrollable factors 
df_acc = df_acc.drop(columns=["Involvement Type","National Road Type","National LGA Name 2021","National Remoteness Areas"])

# %%
# Date Cleaning
df_acc = df_acc.dropna()
df_acc.shape
# Out:
# (55140, 7)

# %%
# Data label
df_acc.iloc[:, 1] = "Road User: " + df_acc.iloc[:, 1].astype(str)
df_acc.iloc[:, 3] = "Age: " + df_acc.iloc[:, 3].astype(str)
df_acc.iloc[:, 6] = "Speed: " + df_acc.iloc[:, 6].astype(str)

# %%
df_acc.head()
# Out:
#   Dayweek             Road User  Gender      Age Group Day of week  \
# 0  Friday     Road User: Driver    Male  Age: 65_to_74     Weekday
# 1  Friday     Road User: Driver  Female  Age: 17_to_25     Weekday
# 2  Friday     Road User: Driver  Female  Age: 26_to_39     Weekday
# 3  Friday     Road User: Driver  Female  Age: 26_to_39     Weekday
# 5  Friday  Road User: Passenger  Female  Age: 40_to_64     Weekday
#
#   Time of day Speed Limit Category
# 0       Night          Speed: High
# 1         Day        Speed: Medium
# 2         Day           Speed: Low
# 3         Day          Speed: High
# 5         Day          Speed: High

# %%
# TransactionEncoder() function only can handle string type
df_new1 = df_acc.astype(str)

# TransactionEncoder() was designed to covert lists to array
list =df_new1.values.tolist()

# Covert the list to one-hot encoded boolean numpy array. 
# Apriori function allows boolean data type only, such as 1 and 0, or FALSE and TRUE.
te = TransactionEncoder()
array_te = te.fit(list).transform(list)

# Check the array
array_te

# Check the colunms
te.columns_

# Apriori function can handle dataframe only, covert the array to a dataframe
df_arm = pd.DataFrame(array_te, columns = te.columns_)

# %%
df_arm.head()
# Out:
#    Age: 0_to_16  Age: 17_to_25  Age: 26_to_39  Age: 40_to_64  Age: 65_to_74  \
# 0         False          False          False          False           True
# 1         False           True          False          False          False
# 2         False          False           True          False          False
# 3         False          False           True          False          False
# 4         False          False          False           True          False
#
#    Age: 75_or_older    Day  Female  Friday   Male  ...  Speed: Low  \
# 0             False  False   False    True   True  ...       False
# 1             False   True    True    True  False  ...       False
# 2             False   True    True    True  False  ...        True
# 3             False   True    True    True  False  ...       False
# 4             False   True    True    True  False  ...       False
#
#    Speed: Medium  Speed: Very High  Speed: Very Low  Sunday  Thursday  \
# 0          False             False            False   False     False
# 1           True             False            False   False     False
# 2          False             False            False   False     False
# 3          False             False            False   False     False
# 4          False             False            False   False     False
#
#    Tuesday  Wednesday  Weekday  Weekend
# 0    False      False     True    False
# 1    False      False     True    False
# 2    False      False     True    False
# 3    False      False     True    False
# 4    False      False     True    False
#
# [5 rows x 30 columns]

# %%
#Find the frequent itemsets
frequent_itemsets = apriori(df_arm,min_support=0.2,use_colnames =True)

#Check the length of rules
frequent_itemsets['length']=frequent_itemsets['itemsets'].apply(lambda x: len(x))

#Assume the length is 2 and the min support is >= 0.3
frequent_itemsets[ (frequent_itemsets['length']==2) & 
                  (frequent_itemsets['support']>=0.3)]
# Out:
#      support                   itemsets  length
# 13  0.382082                (Male, Day)       2
# 16  0.397153             (Weekday, Day)       2
# 17  0.336616              (Night, Male)       2
# 18  0.342202  (Road User: Driver, Male)       2
# 19  0.332680        (Speed: High, Male)       2
# 21  0.412586            (Weekday, Male)       2
# 22  0.306112            (Male, Weekend)       2

# %%
#Assume the min confidence is 0.5
rules_con = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.5)

# %%
#Assume the min lift is 1
rules_lift = association_rules(frequent_itemsets, metric="lift",min_threshold=1)

#Based on min confidence (=0.5), 
#output antecedents, consequents, support, confidence and lift.
result_arm = rules_con[['antecedents','consequents','support','confidence','lift']]

# %%
#Find the rules whose confidence >= 0.5
new_result_arm = result_arm[result_arm['confidence']>=0.5]

ranked_result = new_result_arm.sort_values(by=['lift', 'confidence'], ascending=False)

ranked_result
# Out:
#                          antecedents          consequents   support  \
# 14                           (Night)            (Weekend)  0.236162
# 15                         (Weekend)              (Night)  0.236162
# 26               (Male, Speed: High)  (Road User: Driver)  0.201106
# 25         (Road User: Driver, Male)        (Speed: High)  0.201106
# 16               (Road User: Driver)        (Speed: High)  0.266522
# 17                     (Speed: High)  (Road User: Driver)  0.266522
# 6                              (Day)            (Weekday)  0.397153
# 5                          (Weekday)                (Day)  0.397153
# 23                       (Male, Day)            (Weekday)  0.262223
# 21                   (Weekday, Male)                (Day)  0.262223
# 7                            (Night)               (Male)  0.336616
# 3                      (Speed: High)                (Day)  0.285546
# 4                              (Day)        (Speed: High)  0.285546
# 24  (Road User: Driver, Speed: High)               (Male)  0.201106
# 8                (Road User: Driver)               (Male)  0.342202
# 13                         (Weekend)               (Male)  0.306112
# 20                      (Speed: Low)            (Weekday)  0.201215
# 18               (Road User: Driver)            (Weekday)  0.278292
# 27      (Road User: Driver, Weekday)               (Male)  0.203736
# 28         (Road User: Driver, Male)            (Weekday)  0.203736
# 10                      (Speed: Low)               (Male)  0.236398
# 2                (Road User: Driver)                (Day)  0.259231
# 9                      (Speed: High)               (Male)  0.332680
# 19                     (Speed: High)            (Weekday)  0.272978
# 11                         (Weekday)               (Male)  0.412586
# 12                            (Male)            (Weekday)  0.412586
# 0                             (Male)                (Day)  0.382082
# 1                              (Day)               (Male)  0.382082
# 22                    (Weekday, Day)               (Male)  0.262223
#
#     confidence      lift
# 14    0.550055  1.342690
# 15    0.576475  1.342690
# 26    0.604503  1.329145
# 25    0.587684  1.252410
# 16    0.586012  1.248848
# 17    0.567983  1.248848
# 6     0.695958  1.178922
# 5     0.672760  1.178922
# 23    0.686301  1.162565
# 21    0.635560  1.113736
# 7     0.784025  1.090896
# 3     0.608526  1.066361
# 4     0.500381  1.066361
# 24    0.754559  1.049897
# 8     0.752412  1.046911
# 13    0.747222  1.039689
# 20    0.613119  1.038597
# 18    0.611891  1.036517
# 27    0.732095  1.018641
# 28    0.595368  1.008528
# 10    0.720325  1.002264
# 2     0.569982  0.998817
# 9     0.708974  0.986471
# 19    0.581742  0.985447
# 11    0.698903  0.972458
# 12    0.574075  0.972458
# 0     0.531631  0.931613
# 1     0.669548  0.931613
# 22    0.660258  0.918687
